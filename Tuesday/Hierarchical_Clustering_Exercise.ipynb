# %% [markdown]
# <a href="https://colab.research.google.com/github/Danalmestadi/T5-Week3/blob/main/Hierarchical_Clustering_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Python Implementation using the scikit-learn library**

# %% [markdown]
# #Step 1 : import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.cluster.hierarchy as shc
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage

# %% [markdown]
# #Step 2 : Randomly chosen dataset

# %%
X = np.array([[3, 2], [1, 4], [1, 0],
              [4, 3], [4, 4], [4, 0]])

# %% [markdown]
# #Step 3 : Perform hierarchical clustering  + Ploting

# %%
Z = linkage(X, 'single')

dendrogram(Z)

plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Data point')
plt.ylabel('Distance')
plt.show()
